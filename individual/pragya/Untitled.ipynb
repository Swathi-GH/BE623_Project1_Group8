# %%
from Bio import SeqI0

record = SEQI0.read("nd5.fasta" , "fasta")
print(len(record.seq))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Bio import SeqI0
#       2
#       3 record = SEQI0.read("nd5.fasta" , "fasta")
#       4 print(len(record.seq))
#
# ImportError: cannot import name 'SeqI0' from 'Bio' (/home/pragyasingh/miniconda3/envs/be623/lib/python3.11/site-packages/Bio/__init__.py)
